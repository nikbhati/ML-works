# %%
unlocked_cols = ['Call ID','Unlocked Date','Investor Name','Investor Phone','Scrip',
                 'Advisory Fee','Status','Advisor Name','P/L','Investment','P/L','Status','Type (Intraday/Positional)']

# %%
import pandas as pd
import numpy as np

# %%
unlocked_data=pd.read_csv('UnlockedCalls.csv')

# %%
unlocked_data.head()
# Out:
#                     Call ID    Unlocked Date     Investor Name  \
# 0  5e5608d8e805aa3f8ad3b535  Wed Feb 26 2020               NaN
# 1  5e5608d8e805aa3f8ad3b535  Wed Feb 26 2020           Archana
# 2  5e5608d8e805aa3f8ad3b535  Wed Feb 26 2020  Namandeep Bhatia
# 3  5e5608d8e805aa3f8ad3b535  Wed Feb 26 2020               NaN
# 4  5e5608d8e805aa3f8ad3b535  Wed Feb 26 2020               NaN
#
#    Investor Phone     Scrip  Advisory Fee     Status        Advisor Name  \
# 0      7992209086  RELIANCE           100  COMPLETED  Siddharth Panjwani
# 1      7795007899  RELIANCE           100  COMPLETED  Siddharth Panjwani
# 2      9620361212  RELIANCE           100  COMPLETED  Siddharth Panjwani
# 3      9871896016  RELIANCE           100  COMPLETED  Siddharth Panjwani
# 4      7802862874  RELIANCE           100  COMPLETED  Siddharth Panjwani
#
#      P/L  Investment P/L Status Type (Intraday/Positional)
# 0 -24.35      1404.0       LOSS                 positional
# 1 -24.35      1404.0       LOSS                 positional
# 2 -24.35      1404.0       LOSS                 positional
# 3 -24.35      1404.0       LOSS                 positional
# 4 -24.35      1404.0       LOSS                 positional

# %%
all_data=pd.read_csv('AllCallsData.csv')

# %%
all_data.head()
# Out:
#                     Call ID Call Status      P/L  Investment  \
# 0  5e5608d8e805aa3f8ad3b535   COMPLETED   -24.35    1404.000
# 1  5e562387e805aa3f8ad3b560   COMPLETED   -47.75    6297.750
# 2  5e5624c5e805aa3f8ad3b568   COMPLETED   -13.00    1404.000
# 3  5e562a61e805aa3f8ad3b573   COMPLETED  4222.50  100251.848
# 4  5e562b9ce805aa3f8ad3b577   COMPLETED  2560.00   82310.584
#
#    Unlocked by investors  Advisory Fee Category              Scrip  \
# 0                     11           100     cash           RELIANCE
# 1                      1           100     cash             MARUTI
# 2                      1            50     cash           RELIANCE
# 3                      0           100   future      NIFTY20MARFUT
# 4                      0           100   future  BANKNIFTY20MARFUT
#
#           Advisor Name  Date Call Given Call Status.1  \
# 0   Siddharth Panjwani  Wed Feb 26 2020     COMPLETED
# 1               Swapna  Wed Feb 26 2020     COMPLETED
# 2  Raghuveer S Rathore  Wed Feb 26 2020     COMPLETED
# 3          BABJI ALURI  Wed Feb 26 2020     COMPLETED
# 4          BABJI ALURI  Wed Feb 26 2020     COMPLETED
#
#    Total Amount (Fee*Unlock) Type (Intraday/Positional)  \
# 0                       1100                 positional
# 1                        100                 positional
# 2                         50                 positional
# 3                          0                 positional
# 4                          0                 positional
#
#                  Call Type
# 0    RELIA-cash-positional
# 1    MARUT-cash-positional
# 2    RELIA-cash-positional
# 3  NIFTY-future-positional
# 4  BANKN-future-positional

# %%
unlocked_data=pd.merge(all_data,unlocked_data)

# %%
unlocked_data.head()
# Out:
#                     Call ID Call Status    P/L  Investment  \
# 0  5e5608d8e805aa3f8ad3b535   COMPLETED -24.35      1404.0
# 1  5e5608d8e805aa3f8ad3b535   COMPLETED -24.35      1404.0
# 2  5e5608d8e805aa3f8ad3b535   COMPLETED -24.35      1404.0
# 3  5e5608d8e805aa3f8ad3b535   COMPLETED -24.35      1404.0
# 4  5e5608d8e805aa3f8ad3b535   COMPLETED -24.35      1404.0
#
#    Unlocked by investors  Advisory Fee Category     Scrip        Advisor Name  \
# 0                     11           100     cash  RELIANCE  Siddharth Panjwani
# 1                     11           100     cash  RELIANCE  Siddharth Panjwani
# 2                     11           100     cash  RELIANCE  Siddharth Panjwani
# 3                     11           100     cash  RELIANCE  Siddharth Panjwani
# 4                     11           100     cash  RELIANCE  Siddharth Panjwani
#
#    Date Call Given Call Status.1  Total Amount (Fee*Unlock)  \
# 0  Wed Feb 26 2020     COMPLETED                       1100
# 1  Wed Feb 26 2020     COMPLETED                       1100
# 2  Wed Feb 26 2020     COMPLETED                       1100
# 3  Wed Feb 26 2020     COMPLETED                       1100
# 4  Wed Feb 26 2020     COMPLETED                       1100
#
#   Type (Intraday/Positional)              Call Type    Unlocked Date  \
# 0                 positional  RELIA-cash-positional  Wed Feb 26 2020
# 1                 positional  RELIA-cash-positional  Wed Feb 26 2020
# 2                 positional  RELIA-cash-positional  Wed Feb 26 2020
# 3                 positional  RELIA-cash-positional  Wed Feb 26 2020
# 4                 positional  RELIA-cash-positional  Wed Feb 26 2020
#
#       Investor Name  Investor Phone     Status P/L Status
# 0               NaN      7992209086  COMPLETED       LOSS
# 1           Archana      7795007899  COMPLETED       LOSS
# 2  Namandeep Bhatia      9620361212  COMPLETED       LOSS
# 3               NaN      9871896016  COMPLETED       LOSS
# 4               NaN      7802862874  COMPLETED       LOSS

# %%
unlocked_data.shape
# Out:
# (5423, 19)

# %%
unlocked_callType=unlocked_data.pivot_table(index=['Investor Phone'],columns=['Call Type'],values='P/L',aggfunc=np.sum)

# %%
unlocked_callType
# Out:
# Call Type       3IINF-cash-positional  ABBOT-cash-positional  \
# Investor Phone
# 6006011827                        NaN                    NaN
# 6006048069                        NaN                    NaN
# 6201475920                        NaN                    NaN
# 6203027591                        NaN                    NaN
# 6204115136                        NaN                    NaN
# ...                               ...                    ...
# 9998849841                        NaN                    NaN
# 9998996777                        NaN                    NaN
# 9999012135                        NaN                    NaN
# 9999409726                        NaN                    NaN
# 9999908699                        NaN                    NaN
#
# Call Type       ABCAP-cash-positional  ABFRL-cash-positional  \
# Investor Phone
# 6006011827                        NaN                    NaN
# 6006048069                        NaN                    NaN
# 6201475920                        NaN                    NaN
# 6203027591                        NaN                    NaN
# 6204115136                        NaN                    NaN
# ...                               ...                    ...
# 9998849841                        NaN                    NaN
# 9998996777                        NaN                    NaN
# 9999012135                        NaN                    NaN
# 9999409726                        NaN                    NaN
# 9999908699                        NaN                    NaN
#
# Call Type       ACC-cash-intraday  ACC-cash-positional  \
# Investor Phone
# 6006011827                    NaN                  NaN
# 6006048069                    NaN                  NaN
# 6201475920                    NaN                  NaN
# 6203027591                    NaN                  NaN
# 6204115136                    NaN                  NaN
# ...                           ...                  ...
# 9998849841                    NaN                  NaN
# 9998996777                    NaN                  NaN
# 9999012135                    NaN                  NaN
# 9999409726                    NaN                  NaN
# 9999908699                    NaN                  NaN
#
# Call Type       ACC20-options-positional  ADANI-cash-intraday  \
# Investor Phone
# 6006011827                           NaN                  NaN
# 6006048069                           NaN                  NaN
# 6201475920                           NaN                  NaN
# 6203027591                           NaN                  NaN
# 6204115136                           NaN                  NaN
# ...                                  ...                  ...
# 9998849841                           NaN                  NaN
# 9998996777                           NaN                  NaN
# 9999012135                           NaN                  NaN
# 9999409726                           NaN                  NaN
# 9999908699                           NaN                  NaN
#
# Call Type       ADANI-cash-positional  ADANI-future-intraday  ...  \
# Investor Phone                                                ...
# 6006011827                        NaN                    NaN  ...
# 6006048069                        0.3                    NaN  ...
# 6201475920                        NaN                    NaN  ...
# 6203027591                        NaN                    NaN  ...
# 6204115136                        NaN                    NaN  ...
# ...                               ...                    ...  ...
# 9998849841                        NaN                    NaN  ...
# 9998996777                        NaN                    NaN  ...
# 9999012135                        NaN                    NaN  ...
# 9999409726                        NaN                    NaN  ...
# 9999908699                        NaN                    NaN  ...
#
# Call Type       WIPRO-options-positional  YESBA-cash-intraday  \
# Investor Phone
# 6006011827                           NaN                  NaN
# 6006048069                           NaN                  NaN
# 6201475920                           NaN                  NaN
# 6203027591                           NaN                  NaN
# 6204115136                           NaN                  NaN
# ...                                  ...                  ...
# 9998849841                           NaN                  NaN
# 9998996777                           NaN                  NaN
# 9999012135                           NaN                  NaN
# 9999409726                           NaN                  NaN
# 9999908699                           NaN                  NaN
#
# Call Type       YESBA-cash-positional  YESBA-future-positional  \
# Investor Phone
# 6006011827                        NaN                      NaN
# 6006048069                        NaN                      NaN
# 6201475920                        NaN                      NaN
# 6203027591                        NaN                      NaN
# 6204115136                        NaN                      NaN
# ...                               ...                      ...
# 9998849841                        NaN                      NaN
# 9998996777                        NaN                      NaN
# 9999012135                        NaN                      NaN
# 9999409726                        NaN                      NaN
# 9999908699                        NaN                      NaN
#
# Call Type       YESBA-options-positional  ZEEL-cash-intraday  \
# Investor Phone
# 6006011827                           NaN                 NaN
# 6006048069                           NaN                 NaN
# 6201475920                           NaN                 NaN
# 6203027591                           NaN                 NaN
# 6204115136                           NaN                 NaN
# ...                                  ...                 ...
# 9998849841                           NaN                 NaN
# 9998996777                           NaN                 NaN
# 9999012135                           NaN                 NaN
# 9999409726                           NaN                 NaN
# 9999908699                           NaN                 NaN
#
# Call Type       ZEEL-cash-positional  ZEEL2-options-positional  \
# Investor Phone
# 6006011827                       NaN                       NaN
# 6006048069                       NaN                       NaN
# 6201475920                       NaN                       NaN
# 6203027591                       NaN                       NaN
# 6204115136                       NaN                       NaN
# ...                              ...                       ...
# 9998849841                       NaN                       NaN
# 9998996777                       NaN                       NaN
# 9999012135                       NaN                       NaN
# 9999409726                      14.9                       NaN
# 9999908699                       NaN                       NaN
#
# Call Type       ZENSA-cash-positional  ZYDUS-cash-positional
# Investor Phone
# 6006011827                        NaN                    NaN
# 6006048069                        NaN                    NaN
# 6201475920                        NaN                    NaN
# 6203027591                        NaN                    NaN
# 6204115136                        NaN                    NaN
# ...                               ...                    ...
# 9998849841                        NaN                    NaN
# 9998996777                        NaN                    NaN
# 9999012135                        NaN                    NaN
# 9999409726                        NaN                    NaN
# 9999908699                        NaN                    NaN
#
# [2652 rows x 447 columns]

# %%
nifty_fut_positional_PnL=unlocked_callType['NIFTY-future-positional']

# %%
nifty_fut_positional_PnL
# Out:
# Investor Phone
# 6006011827   NaN
# 6006048069   NaN
# 6201475920   NaN
# 6203027591   NaN
# 6204115136   NaN
#               ..
# 9998849841   NaN
# 9998996777   NaN
# 9999012135   NaN
# 9999409726   NaN
# 9999908699   NaN
# Name: NIFTY-future-positional, Length: 2652, dtype: float64

# %%
similar_calls=unlocked_callType.corrwith(nifty_fut_positional_PnL)
# Out:
# C:\Users\nikunjbhatia\anaconda3\lib\site-packages\numpy\lib\function_base.py:2526: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# C:\Users\nikunjbhatia\anaconda3\lib\site-packages\numpy\lib\function_base.py:2455: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
similar_calls=similar_calls.dropna()

# %%
df=pd.DataFrame(similar_calls)

# %%
df=df.sort_values(by=[0],ascending=False)

# %%
df
# Out:
#                                  0
# Call Type
# VOLTA-cash-positional     1.000000
# NIFTY-future-positional   1.000000
# NIFTY-future-intraday     1.000000
# LT-cash-positional        1.000000
# L&TFH-cash-positional     1.000000
# HDFC-cash-positional      1.000000
# NAM-I-cash-positional     1.000000
# RELIA-cash-intraday       0.919597
# ADANI-cash-positional     0.839913
# IDEA-cash-positional      0.825837
# BHART-cash-positional     0.808106
# NIFTY-options-positional  0.277623
# BANKN-options-positional  0.272220
# RELIA-cash-positional    -0.229246
# ICICI-cash-positional    -0.638095
# SBIN-cash-positional     -0.659644
# RELIA-options-positional -0.707717
# SPENC-cash-positional    -0.852905
# BANKN-future-positional  -0.860493
# SUNPH-cash-positional    -0.943455
# DELTA-cash-positional    -1.000000
# MOTHE-cash-positional    -1.000000
# ALOKI-cash-positional    -1.000000
# PEL-cash-intraday        -1.000000
# CENTU-cash-positional    -1.000000
# TRENT-cash-positional    -1.000000

# %%
corrMat=
